# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
img = cv2.imread('derp_img.jpg',0)
plt.imshow(img)

# %%
img_new = 255-cv2.resize(img,(28,28))
plt.imshow(img_new)

# %%
cv2.imwrite('derp_test.jpg',img_new)
# Out:
# True
